# %% [markdown]
# # Welcome to Unit 1!

# %% [markdown]
# Workshop 1 videos are shown below:
#
# **Variables, If Statements, Loops**
# <div style="position: relative; padding-bottom: 56.25%; height: 0;"><iframe src="https://www.loom.com/embed/fcb30d76198b4977afa4accafdafd025" frameborder="0" webkitallowfullscreen mozallowfullscreen allowfullscreen style="position: absolute; top: 0; left: 0; width: 100%; height: 100%;"></iframe></div>
#
# **Lists, Tuples, Dictionaries**
# <div style="position: relative; padding-bottom: 56.25%; height: 0;"><iframe src="https://www.loom.com/embed/c61740221a8447df99039e1b5306dd1c" frameborder="0" webkitallowfullscreen mozallowfullscreen allowfullscreen style="position: absolute; top: 0; left: 0; width: 100%; height: 100%;"></iframe></div>

# %% [markdown]
# As you have seen from the welcome video, the objective of this Udemy course is to get you acclimated with the fundamentals of data science through the
# introduction of the data science pipeline. These days, a lot of data science is done with Python. As such we will be using Python in this course for the following reasons (but not limited to):
#
# 1. Relatively simple syntax
# 2. Availability of well-maintained and open-source libraries
# 3. Huge developer support + community

# %%
# Start writing code here...
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# In `exercise.py`, you will find a set of tasks to complete in order to ramp up your foundations. There is also a file called `tester.py` that you can run in order to see if your implementation works (through unit tests). Couple pieces of advice:
#
# 1. Take your time with this exercise. You want to make sure that you clearly understand the problem that is presented
#
# 2. Don't just copy solutions off of the Internet blindly. You can use resources such as Stack Overflow as helpers, but don't substitute the actual learning just for "completing the exercise". Your goal is to sharpen your problem solving
#
# 3. Collaborate at the "whiteboard-level" (like discuss approaches at high level/bounce ideas, but not exactly specific implementation details)
#
# 4. Work with other students in the Udemy Course (we have a Slack channel after all that you joined). Please refrain from sharing your solutions to the group. We would hate if the meat and potatoes of the problems got "spoiled".
#
# Good luck in this exercise!

# %% [markdown]
# Feel free to create code cells to debug your exercise. Don't forget to `import exercise` in this notebook in order to invoke functions within this notebook. See the below cells:

# %%
import exercise

# %%
exercise.cube(4)
# Out:
# 64

# %% [markdown]
# To test that your code works, you can go to the right sidebar and under `Terminals`, you'll see an entry called `Sandbox Terminal`. Open that terminal and run `python tester.py`

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cc653ff8-5d2b-4ea3-a72d-6a9cbdd4861f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
