# %%
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_boston

boston = load_boston()

x = boston.data
y = boston.target

df = pd.DataFrame(x, y)

boston.keys()

print(boston.feature_names)

#df

print(df.shape) #im getting 506 x 13 instead of 506 x 14
#df.info()

#1) 506 x 13
#2) no
#3) 
crim_mean = df[0].mean() #i can't actually call CRIM and RM
print(crim_mean)

rm_mean = df[5].mean()
print(rm_mean)

nox_max = df[4].max()
print(nox_max)

age_med = df[6].median()
print(age_med)

tax = df[9].std()
print(tax)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# (506, 13)
# 3.613523557312254
# 6.284634387351779
# 0.871
# 77.5
# 168.53711605495903
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.datasets import load_boston

boston = load_boston()

x = boston.data
y = boston.target

df = pd.DataFrame(x, y)

boston.keys()

print(boston.feature_names)

#4)
df = df.drop([11, 12], axis = 1) #how do i drop medv when it's not there

df = df[df[3] != 1]

quant = np.percentile(df[4], 75)
df = df[df[4] < quant]

df = df[df[6] > age_med]

print(df.shape) #getting 107 x 11 which is good i guess!

sns.distplot(df[5]) #normal distribution!!!
sns.distplot(df[7]) #right skewed!!
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# (107, 11)
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4df135df-d83c-4d03-b780-991459f5bda1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
