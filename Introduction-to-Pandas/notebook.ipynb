# %% [markdown]
# # Week 2: Introduction to Pandas
# As you have seen from the video, `pandas` is a popular Python library that is commonly used for data retrieval and manipulation tasks. This drill will help you get acclimated to the power of Pandas

# %% [markdown]
# In `exercise.py`, you will find a set of tasks to complete in order to ramp up your foundations. There is also a file called `tester.py` that you can run in order to see if your implementation works (through unit tests). Couple pieces of advice:
#
# 1. Take your time with this exercise. You want to make sure that you clearly understand the problem that is presented
#
# 2. Don't just copy solutions off of the Internet blindly. You can use resources such as Stack Overflow as helpers, but don't substitute the actual learning just for "completing the exercise". Your goal is to sharpen your problem solving
#
# 3. Collaborate at the "whiteboard-level" (like discuss approaches at high level/bounce ideas, but not exactly specific implementation details)
#
# 4. Work with other students in the Udemy Course (we have a Slack channel after all that you joined). Please refrain from sharing your solutions to the group. We would hate if the meat and potatoes of the problems got "spoiled".
#
# Good luck in this exercise!

# %% [markdown]
# Below are some cells you can run to double check your implementation

# %%
import exercise
import pandas as pd
import seaborn as sns

df = pd.read_csv('titanic_train.csv')

# %%
#see what the dataframe looks like for purposes of this exercise
exercise.get_dataframe()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Exercise 1

# %%
exercise.get_age_class_sex()

# %% [markdown]
# ## Exercise 2

# %%
exercise.get_age_class_sex_over_30()

# %% [markdown]
# ## Exercise 3

# %%
exercise.get_100th_person_info()

# %% [markdown]
# ## Exercise 4

# %%
exercise.calc_num_unique_ages()

# %% [markdown]
# ## Exercise 5

# %%
exercise.get_cabin_nulls_and_shape()

# %% [markdown]
# ## Exercise 6

# %%
exercise.drop_cabin_col()

# %% [markdown]
# ## Exercise 7

# %%
exercise.survived_within_class()

# %% [markdown]
# To test that your code works, you can go to the right sidebar and under `Terminals`, you'll see an entry called `Sandbox Terminal`. Open that terminal and run `python tester.py`

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3d0133b3-1875-4d7e-bf20-33b408f85deb' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
